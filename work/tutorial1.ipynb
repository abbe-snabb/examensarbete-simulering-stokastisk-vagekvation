# %%
using Gridap

# %%
model = DiscreteModelFromFile("./Tutorials/models/model.json")
# Out:
# UnstructuredDiscreteModel()

# %%
writevtk(model,"model")
# Out:
# 4-element Vector{Vector{String}}:
#  ["model_0.vtu"]
#  ["model_1.vtu"]
#  ["model_2.vtu"]
#  ["model_3.vtu"]

# %%
order = 1
reffe = ReferenceFE(lagrangian,Float64,order)
V0 = TestFESpace(model,reffe;conformity=:H1,dirichlet_tags="sides")
# Out:
# UnconstrainedFESpace()

# %%
g(x) = 2.0
Ug = TrialFESpace(V0,g)
# Out:
# TrialFESpace()

# %%
degree = 2
Ω = Triangulation(model)
dΩ = Measure(Ω,degree)
# Out:
# GenericMeasure()

# %%
neumanntags = ["circle", "triangle", "square"]
Γ = BoundaryTriangulation(model,tags=neumanntags)
dΓ = Measure(Γ,degree)
# Out:
# GenericMeasure()

# %%
f(x) = 1.0
h(x) = 3.0
a(u,v) = ∫( ∇(v)⋅∇(u) )*dΩ
b(v) = ∫( v*f )*dΩ + ∫( v*h )*dΓ
# Out:
# b (generic function with 1 method)

# %%
op = AffineFEOperator(a,b,Ug,V0)
# Out:
# AffineFEOperator()

# %%
ls = LUSolver()
solver = LinearFESolver(ls)
# Out:
# LinearFESolver()

# %%
uh = solve(solver,op)
# Out:
# SingleFieldFEFunction():
#  num_cells: 29160
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 1410203149619722791

# %%
writevtk(Ω,"results",cellfields=["uh"=>uh])
# Out:
# (["results.vtu"],)
