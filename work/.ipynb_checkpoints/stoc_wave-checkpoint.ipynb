# %%
import Gmsh: gmsh 
import Pkg; Pkg.add("Distributions"); 
using Gridap, GridapGmsh 
using Random 
using Distributions 
using Base.Threads 
using LinearAlgebra 
using Plots 

BLAS.set_num_threads(1)
# Out:
# ┌ Warning: attempting to remove probably stale pidfile
# │   path = "/root/.julia/registries/.pid"
# └ @ FileWatching.Pidfile /usr/local/julia/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:278
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`

# %%
function create_square_model(h)
    gmsh.initialize()
    gmsh.model.add("unit_square")
    gmsh.model.geo.addPoint(0,0,0,1,1) # last argument is optional identifier, unique per dimension
    gmsh.model.geo.addPoint(1,0,0,1,2)
    gmsh.model.geo.addPoint(1,1,0,1,3)
    gmsh.model.geo.addPoint(0,1,0,1,4)
    gmsh.model.geo.addLine(1,2,1)
    gmsh.model.geo.addLine(2,3,2) # line 2 goes from point 2 to point 3
    gmsh.model.geo.addLine(3,4,3)
    gmsh.model.geo.addLine(4,1,4)
        
    gmsh.model.geo.addCurveLoop([1,2,3,4],1)
        
    gmsh.model.geo.addPlaneSurface([1],1)

    N = Int(round(1/h))  # number of elements per edge

    gmsh.model.geo.mesh.setTransfiniteCurve(1, N+1)
    gmsh.model.geo.mesh.setTransfiniteCurve(2, N+1)
    gmsh.model.geo.mesh.setTransfiniteCurve(3, N+1)
    gmsh.model.geo.mesh.setTransfiniteCurve(4, N+1)

    #triangulation
    gmsh.model.geo.mesh.setTransfiniteSurface(1)

    gmsh.model.geo.synchronize()

    # Define physical groups without the string argument
    edges_tag = gmsh.model.addPhysicalGroup(1, [1, 2, 3, 4])   # edges
    corners_tag = gmsh.model.addPhysicalGroup(0, [1, 2, 3, 4]) # corners
    domain_tag = gmsh.model.addPhysicalGroup(2, [1])           # surface
    
    # Set names for the physical groups
    gmsh.model.setPhysicalName(1, edges_tag, "boundary")
    gmsh.model.setPhysicalName(0, corners_tag, "boundary")
    gmsh.model.setPhysicalName(2, domain_tag, "domain")
    gmsh.model.mesh.generate(2)

    model = GmshDiscreteModel(gmsh);
    gmsh.finalize();
    return model
end
# Out:
# create_square_model (generic function with 1 method)

# %%
h = 2^-4; # target mesh size 
model = create_square_model(h) # fix above function above using the tutorial 
order = 1 
reffe = ReferenceFE(lagrangian, Float64, order) 
V = TestFESpace(model, reffe, conformity=:H1, dirichlet_tags="boundary") 
U = TrialFESpace(V, 0.0) 
Ω = Triangulation(model) 
dΩ = Measure(Ω, 2 * order) 
n=8 
Δt, T = 2.0^(-n), 1 # time step, final time 
num_steps = Int(round(T / Δt)) 
f(x) = x[1]*(1-x[1]) *x[2]*(1-x[2]) #sin(x[1]*pi)*sin(x[2]*pi) 
fx = x->f(x) 
u₀ = x -> 0.0 
v₀ = x -> 0.0 
m(u, v) = ∫(u*v)dΩ 
k(u, v) = ∫(∇(u) ⋅ ∇(v))dΩ 
Mmat = assemble_matrix(m, U, V) 
Kmat = assemble_matrix(k, U, V) 
LHSpos = (2/Δt)*Mmat + (Δt/2)*Kmat 
RHSpos = (2/Δt)*Mmat - (Δt/2)*Kmat 
uh0 = interpolate_everywhere(u₀, U) # U^0 
vh0 = interpolate_everywhere(v₀, U) # V^0
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.000768437s, CPU 0.000766s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Transfinite)
# Info    : Done meshing 2D (Wall 0.0012292s, CPU 0.00114s)
# Info    : 289 nodes 580 elements
# SingleFieldFEFunction():
#  num_cells: 512
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 4242097911729422507

# %%
if !isdir("tmp") mkdir("tmp") end

createpvd("wave") do pvd
    pvd[0.0] = createvtk(
        Ω,
        "tmp/stoc_wavev2_0.vtu",
        cellfields = ["uh" => uh0, "vh" => vh0]
    )

    # dof-vectors
    uvec = get_free_dof_values(uh0)  # U^0
    vvec = get_free_dof_values(vh0)  # V^0

    b(v) = ∫(fx * v)dΩ
    Fn = assemble_vector(b, V)
    
    for n in 1:(num_steps-1)
        t_n = n * Δt
        Δβ = rand(Normal(0, sqrt(Δt)))
        noise = Δβ * Fn

        # Solve for U^n
        rhs_u = RHSpos * uvec + (2 * Mmat) * vvec + 2 * noise
        uvec_new = LHSpos \ rhs_u

        # update V^n
        rhs_v = Mmat * vvec - (Δt / 2) * Kmat * (uvec_new + uvec) + noise
        # rhs_v = ((2/Δt) * M) * (uvec_new - uvec) - M*vvec - noise
        vvec_new = Mmat \ rhs_v

        uh = FEFunction(U, uvec_new)
        vh = FEFunction(U, vvec_new)
        
        # save
        vtufilename = "tmp/stoc_wavev2_$(n).vtu"
        pvd[t_n] = createvtk(
            Ω,
            vtufilename,
            cellfields = ["uh" => uh, "vh" => vh]
        )

        # update
        uvec = uvec_new
        vvec = vvec_new
    end
end
# Out:
# 257-element Vector{String}:
#  "wave.pvd"
#  "tmp/stoc_wavev2_0.vtu"
#  "tmp/stoc_wavev2_1.vtu"
#  "tmp/stoc_wavev2_2.vtu"
#  "tmp/stoc_wavev2_3.vtu"
#  "tmp/stoc_wavev2_4.vtu"
#  "tmp/stoc_wavev2_5.vtu"
#  "tmp/stoc_wavev2_6.vtu"
#  "tmp/stoc_wavev2_7.vtu"
#  "tmp/stoc_wavev2_8.vtu"
#  "tmp/stoc_wavev2_9.vtu"
#  "tmp/stoc_wavev2_10.vtu"
#  "tmp/stoc_wavev2_11.vtu"
#  ⋮
#  "tmp/stoc_wavev2_244.vtu"
#  "tmp/stoc_wavev2_245.vtu"
#  "tmp/stoc_wavev2_246.vtu"
#  "tmp/stoc_wavev2_247.vtu"
#  "tmp/stoc_wavev2_248.vtu"
#  "tmp/stoc_wavev2_249.vtu"
#  "tmp/stoc_wavev2_250.vtu"
#  "tmp/stoc_wavev2_251.vtu"
#  "tmp/stoc_wavev2_252.vtu"
#  "tmp/stoc_wavev2_253.vtu"
#  "tmp/stoc_wavev2_254.vtu"
#  "tmp/stoc_wavev2_255.vtu"

# %% [markdown]
# ## Convergence Testing ##

# %%
function EMpath_stoch_time(uh0, vh0, T, Nref, kappa, facLHS, facM, Mmat, Kmat, Fvec, rng)
    Dtref = T / Nref
    Dt = kappa * Dtref
    NN = div(Nref, kappa)

    # precompute to avoid doing it for every timestep
    a = 2 / Dt
    b = Dt / 2
    sqrtDtref = sqrt(Dtref)

    # copy uh0 and vh0 to avoid modifying the original
    uvec = copy(get_free_dof_values(uh0))
    vvec = copy(get_free_dof_values(vh0))

    # allocate memory for all the arrays in the loop to avoid allocating garbage every time step
    uvec_new = similar(uvec)
    vvec_new = similar(vvec)

    Mu = similar(uvec)
    Ku = similar(uvec)
    Mv = similar(uvec)
    usum = similar(uvec)

    rhs_u = similar(uvec)
    rhs_v = similar(uvec)

    for n in 1:NN
        Δβ = 0.0
        @inbounds for r in 1:kappa
            Δβ += sqrtDtref * randn(rng)
        end

        # Mu = Mmat * uvec
        mul!(Mu, Mmat, uvec)

        # Ku = Kmat * uvec
        mul!(Ku, Kmat, uvec)

        # Mv = Mmat * vvec
        mul!(Mv, Mmat, vvec)

        # rhs_u = (2/Dt) * M*u - (Dt/2) * K*u + 2*M*v + 2*Δβ*F
        rhs_u .= a .* Mu .- b .* Ku .+ 2.0 .* Mv .+ 2.0 .* Δβ .* Fvec

        copyto!(uvec_new, rhs_u)
        ldiv!(facLHS, uvec_new)

        # usum = uvec_new + uvec
        usum .= uvec_new .+ uvec

        # Ku = Kmat * (uvec_new + uvec)
        mul!(Ku, Kmat, usum)

        # rhs_v = M*v - (Dt/2) * K*(u_new + u_old) + Δβ*F
        rhs_v .= Mv .- b .* Ku .+ Δβ .* Fvec

        copyto!(vvec_new, rhs_v)
        ldiv!(facM, vvec_new)

        uvec, uvec_new = uvec_new, uvec
        vvec, vvec_new = vvec_new, vvec
    end

    return uvec
end


function EMpath_space(uh0, vh0, num_steps, Δt, facLHS, facM, Mmat, Kmat, Fvec, rng)
    a = 2 / Δt
    b = Δt / 2
    sqrtΔt = sqrt(Δt)

    uvec = copy(get_free_dof_values(uh0))
    vvec = copy(get_free_dof_values(vh0))

    uvec_new = similar(uvec)
    vvec_new = similar(uvec)

    Mu = similar(uvec)
    Ku = similar(uvec)
    Mv = similar(uvec)
    usum = similar(uvec)

    rhs_u = similar(uvec)
    rhs_v = similar(uvec)

    for n in 1:num_steps
        Δβ = sqrtΔt * randn(rng)

        mul!(Mu, Mmat, uvec)
        mul!(Ku, Kmat, uvec)
        mul!(Mv, Mmat, vvec)
        
        # rhs_u = (2/Dt) * M*u - (Dt/2) * K*u + 2*M*v + 2*Δβ*F
        rhs_u .= a .* Mu .- b .* Ku .+ 2.0 .* Mv .+ 2.0 .* Δβ .* Fvec
        copyto!(uvec_new, rhs_u)
        ldiv!(facLHS, uvec_new)

        usum .= uvec_new .+ uvec
        mul!(Ku, Kmat, usum)
        # rhs_v = M*v - (Dt/2) * K*(u_new + u_old) + Δβ*F
        rhs_v .= Mv .- b .* Ku .+ Δβ .* Fvec
        copyto!(vvec_new, rhs_v)
        ldiv!(facM, vvec_new)

        uvec, uvec_new = uvec_new, uvec
        vvec, vvec_new = vvec_new, vvec
    end

    return uvec
end
# Out:
# EMpath_space (generic function with 1 method)

# %%
function runEMpath_stoch_time(uh0, vh0, T, Nref, kappas, Nsamp, Mmat, Kmat, Fvec)
    nk = length(kappas)         # number of kappas
    Dtref = T / Nref            # time step for reference
    ndofs = length(Fvec)        # number of degrees of freedom

    partial_sums = [zeros(nk) for _ in 1:nthreads()]  # one vector per thread to compute sum and avoid race conditions

    facM = lu(Mmat)  # pre-LU factorization of mass matrix

    # pre-LU factorize the LHS matrix of the ref
    Dt1 = Dtref
    LHSpos1 = (2 / Dt1) * Mmat + (Dt1 / 2) * Kmat
    facLHS1 = lu(LHSpos1)

    # pre-LU factorize the LHS matrix for the kappas
    facLHS_list = Vector{typeof(facLHS1)}(undef, nk)
    for (i, kappa) in enumerate(kappas)
        Dt = kappa * Dtref
        LHSpos = (2 / Dt) * Mmat + (Dt / 2) * Kmat
        facLHS_list[i] = lu(LHSpos)
    end

    @threads for samp in 1:Nsamp
        tid = threadid()                  # thread index
        local_sum = partial_sums[tid]     # the thread's own vector to compute sum later

        seed = 1337 + samp                # every sample gets new seed

        rng1 = Xoshiro(seed)
        uref = EMpath_stoch_time(uh0, vh0, T, Nref, 1, facLHS1, facM, Mmat, Kmat, Fvec, rng1)

        Merr = zeros(ndofs)               # allocate vector to avoid new ones being created for every kappa

        for (i, kappa) in enumerate(kappas)
            rng2 = Xoshiro(seed)          # same seed for rng2
            u = EMpath_stoch_time(uh0, vh0, T, Nref, kappa, facLHS_list[i], facM, Mmat, Kmat, Fvec, rng2)

            # compute error
            erru = u - uref
            mul!(Merr, Mmat, erru)
            local_sum[i] += dot(erru, Merr)
        end
    end

    # add all thread vectors to get final vector
    S_u = zeros(nk)
    for ps in partial_sums
        S_u .+= ps
    end

    return sqrt.(S_u ./ Nsamp)
end


function runEMpath_stoch_space(T, Nref, kappas, Nsamp)
    nk = length(kappas)  # number of kappas

    # reference mesh first, then coarse meshes
    N_list = [Nref; (Nref ./ kappas)]

    # fixed time step
    n_time = 5
    Δt = 2.0^(-n_time)
    num_steps = Int(round(T / Δt))

    # storage for matrices
    M_list   = Vector{Any}(undef, nk+1)
    K_list   = Vector{Any}(undef, nk+1)
    F_list   = Vector{Any}(undef, nk+1)
    U_list   = Vector{Any}(undef, nk+1)
    uh0_list = Vector{Any}(undef, nk+1)
    vh0_list = Vector{Any}(undef, nk+1)

    order = 1
    reffe = ReferenceFE(lagrangian, Float64, order)

    # build all meshes
    for i in 1:(nk+1)
        N = N_list[i]
        h = 1 / N

        model = create_square_model(h)

        V = TestFESpace(model, reffe, conformity=:H1, dirichlet_tags="boundary")
        U_list[i] = TrialFESpace(V, 0.0)

        Ω = Triangulation(model)
        dΩ = Measure(Ω, 2 * order)

        f(x) = x[1] * (1 - x[1]) * x[2] * (1 - x[2])

        m(u, v) = ∫(u * v)dΩ
        k(u, v) = ∫(∇(u) ⋅ ∇(v))dΩ
        b(v) = ∫(f * v)dΩ

        M_list[i] = assemble_matrix(m, U_list[i], V)
        K_list[i] = assemble_matrix(k, U_list[i], V)
        F_list[i] = assemble_vector(b, V)

        uh0_list[i] = interpolate_everywhere(x -> 0.0, U_list[i])
        vh0_list[i] = interpolate_everywhere(x -> 0.0, U_list[i])
    end

    # factorizations
    facM_list = [lu(M_list[i]) for i in 1:(nk+1)]
    facLHS_list = [lu((2 / Δt) * M_list[i] + (Δt / 2) * K_list[i]) for i in 1:(nk+1)]

    partial_sums = [zeros(nk) for _ in 1:nthreads()]

    # reference objects
    Mref = M_list[1]
    Uref = U_list[1]

    @threads for samp in 1:Nsamp
        tid = threadid()
        local_sum = partial_sums[tid]

        seed = 1337 + samp

        rng1 = Xoshiro(seed)
        uref = EMpath_space(
            uh0_list[1], vh0_list[1], num_steps, Δt,
            facLHS_list[1], facM_list[1], M_list[1], K_list[1], F_list[1], rng1
        )

        Merr = similar(uref)

        for i in 1:nk
            idx = i + 1   # skip ref mesh

            rng2 = Xoshiro(seed)

            u = EMpath_space(
                uh0_list[idx], vh0_list[idx], num_steps, Δt,
                facLHS_list[idx], facM_list[idx], M_list[idx], K_list[idx], F_list[idx], rng2
            )

            # coarse FE function
            uh = FEFunction(U_list[idx], u)

            # interpolate coarse solution onto reference space
            uh_ref = interpolate_everywhere(x -> uh(x), Uref)
            u_interp = get_free_dof_values(uh_ref)

            # error
            err = u_interp - uref
            mul!(Merr, Mref, err)
            local_sum[i] += dot(err, Merr)
        end
    end

    S = zeros(nk)
    for ps in partial_sums
        S .+= ps
    end

    return sqrt.(S ./ Nsamp)
end
# Out:
# runEMpath_stoch_space (generic function with 1 method)

# %%
T = 1
kappas = [2,4,8,16,32,64,128,256,512,1024]
Nref = 2^12
Nsamp = 20

b(v) = ∫(fx * v)dΩ
Fvec = assemble_vector(b, V)

@time begin
    rms_u_time = runEMpath_stoch_time(uh0, vh0, T, Nref, kappas, Nsamp, Mmat, Kmat, Fvec)
end

Dtref = T / Nref
dts = kappas .* Dtref

Nref_space = 2^5
kappas_space = [2,4,8,16]
Nsamp_space = 20

@time begin
    rms_u_space = runEMpath_stoch_space(T, Nref_space, kappas_space, Nsamp_space)
end

lenref = 1 ./ Nref_space
hs = kappas_space .* lenref

println("number of threads:")
println(nthreads())

println("----------------------------TIME----------------------------")
println("dt values:")
println(dts)
println("RMS errors:")
println(rms_u_time)
println("------------------------------------------------------------")

println("")

println("----------------------------SPACE----------------------------")
println("h values:")
println(hs)
println("RMS errors:")
println(rms_u_space)
println("-------------------------------------------------------------")
# Out:
#   3.656539 seconds (4.50 M allocations: 807.757 MiB, 4.78% gc time, 77593 lock conflicts, 322.30% compilation time)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.000106884s, CPU 0.000108s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Transfinite)
# Info    : Done meshing 2D (Wall 0.00013181s, CPU 0.000124s)
# Info    : 1089 nodes 2180 elements
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 9.8867e-05s, CPU 0.000101s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Transfinite)
# Info    : Done meshing 2D (Wall 6.9796e-05s, CPU 6.5e-05s)
# Info    : 289 nodes 580 elements
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.000112236s, CPU 0.000117s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Transfinite)
# Info    : Done meshing 2D (Wall 4.8071e-05s, CPU 4.6e-05s)
# Info    : 81 nodes 164 elements
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.000118847s, CPU 0.000136s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Transfinite)
# Info    : Done meshing 2D (Wall 6.8819e-05s, CPU 6.7e-05s)
# Info    : 25 nodes 52 elements
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 8.6508e-05s, CPU 9.1e-05s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Transfinite)
# Info    : Done meshing 2D (Wall 1.4308e-05s, CPU 1.4e-05s)
# Info    : 9 nodes 20 elements
#  10.240953 seconds (384.21 M allocations: 30.126 GiB, 50.93% gc time, 227 lock conflicts, 367.73% compilation time)
# number of threads:
# 20
# ----------------------------TIME----------------------------
# dt values:
# [0.00048828125, 0.0009765625, 0.001953125, 0.00390625, 0.0078125, 0.015625, 0.03125, 0.0625, 0.125, 0.25]
# RMS errors:
# [4.148852139007849e-6, 1.1001880114799653e-5, 3.105085668864397e-5, 6.203394445257479e-5, 0.00010258884963564597, 0.0001980898254588611, 0.0003855549368122709, 0.0008214918284833936, 0.0015620627376385055, 0.0021680717350429884]
# ------------------------------------------------------------
#
# ----------------------------SPACE----------------------------
# h values:
# [0.0625, 0.125, 0.25, 0.5]
# RMS errors:
# [5.7958144844920044e-5, 0.0002768177656753058, 0.0010656516368512557, 0.003654962883392028]
# -------------------------------------------------------------

# %%
x = range(minimum(dts), maximum(dts), 100)

# log-log plot time
plot(dts, rms_u_time, xaxis=:log, yaxis=:log,
     marker=:cross, markercolor=:black, linecolor=:blue, label="RMS error")
plot!(x, 0.2 * x.^1, xaxis=:log, yaxis=:log, linecolor=:red, label="Reference line")

# %%
y = range(minimum(hs), maximum(hs), 100)

# log-log plot space
plot(hs, rms_u_space, xaxis=:log, yaxis=:log,
     marker=:cross, markercolor=:black, linecolor=:blue, label="RMS error")
plot!(y, 0.2 * y.^1, xaxis=:log, yaxis=:log, linecolor=:red, label="Reference line")
