# %%
using Gridap

u(x) = x[1] + x[2]
f(x) = 0
# Out:
# f (generic function with 1 method)

# %%
∇u(x) = VectorValue(1,1)
# Out:
# ∇u (generic function with 1 method)

# %%
import Gridap: ∇
∇(::typeof(u)) = ∇u
# Out:
# gradient (generic function with 39 methods)

# %%
∇(u) === ∇u
# Out:
# true

# %%
domain = (0,1,0,1)
partition = (4,4)
model = CartesianDiscreteModel(domain,partition)
# Out:
# CartesianDiscreteModel()

# %%
domain3d = (0,1,0,1,0,1)
partition3d = (4,4,4)
model3d = CartesianDiscreteModel(domain3d,partition3d)
# Out:
# CartesianDiscreteModel()

# %%
writevtk(model3d,"model3d")
# Out:
# 4-element Vector{Vector{String}}:
#  ["model3d_0.vtu"]
#  ["model3d_1.vtu"]
#  ["model3d_2.vtu"]
#  ["model3d_3.vtu"]

# %%
order = 1
reffe = ReferenceFE(lagrangian,Float64,order)
V0 = TestFESpace(model,reffe,conformity=:H1,dirichlet_tags="boundary")
U = TrialFESpace(V0,u)

degree = 2
Ω = Triangulation(model)
dΩ = Measure(Ω,degree)

a(u,v) = ∫( ∇(v)⊙∇(u) )*dΩ
b(v) = ∫( v*f )*dΩ

op = AffineFEOperator(a,b,U,V0)

uh = solve(op)
# Out:
# SingleFieldFEFunction():
#  num_cells: 16
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 12655890970943489580

# %%
e = u - uh
# Out:
# OperationCellField():
#  num_cells: 16
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 12655890970943489580

# %%
writevtk(Ω,"error",cellfields=["e" => e])
# Out:
# (["error.vtu"],)

# %%
el2 = sqrt(sum( ∫( e*e )*dΩ ))
eh1 = sqrt(sum( ∫( e*e + ∇(e)⋅∇(e) )*dΩ ))
# Out:
# 1.0241643448331112e-15

# %%
tol = 1.e-10
@assert el2 < tol
@assert eh1 < tol

# %%
p = 3
u(x) = x[1]^p+x[2]^p
∇u(x) = VectorValue(p*x[1]^(p-1),p*x[2]^(p-1))
f(x) = -p*(p-1)*(x[1]^(p-2)+x[2]^(p-2))
# Out:
# f (generic function with 1 method)

# %%
∇(::typeof(u)) = ∇u
b(v) = ∫( v*f )*dΩ
# Out:
# b (generic function with 1 method)

# %%
function run(n,k)

  domain = (0,1,0,1)
  partition = (n,n)
  model = CartesianDiscreteModel(domain,partition)

  reffe = ReferenceFE(lagrangian,Float64,k)
  V0 = TestFESpace(model,reffe,conformity=:H1,dirichlet_tags="boundary")
  U = TrialFESpace(V0,u)

  degree = 2*p
  Ω = Triangulation(model)
  dΩ = Measure(Ω,degree)

  a(u,v) = ∫( ∇(v)⊙∇(u) )*dΩ
  b(v) = ∫( v*f )*dΩ

  op = AffineFEOperator(a,b,U,V0)

  uh = solve(op)

  e = u - uh

  el2 = sqrt(sum( ∫( e*e )*dΩ ))
  eh1 = sqrt(sum( ∫( e*e + ∇(e)⋅∇(e) )*dΩ ))

  (el2, eh1)

end
# Out:
# run (generic function with 1 method)

# %%
function conv_test(ns,k)

  el2s = Float64[]
  eh1s = Float64[]
  hs = Float64[]

  for n in ns

    el2, eh1 = run(n,k)
    h = 1.0/n

    push!(el2s,el2)
    push!(eh1s,eh1)
    push!(hs,h)

  end

  (el2s, eh1s, hs)

end
# Out:
# conv_test (generic function with 1 method)

# %%
el2s1, eh1s1, hs = conv_test([8,16,32,64,128],1);
el2s2, eh1s2, hs = conv_test([8,16,32,64,128],2);
nothing #hide

# %%
import Pkg
Pkg.add("Plots")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed LoggingExtras ──────────────── v1.2.0
#    Installed LERC_jll ───────────────────── v4.0.1+0
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed Opus_jll ───────────────────── v1.5.2+0
#    Installed x265_jll ───────────────────── v4.1.0+0
#    Installed GR_jll ─────────────────────── v0.73.19+1
#    Installed libfdk_aac_jll ─────────────── v2.0.4+0
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.7+0
#    Installed ConcurrentUtilities ────────── v2.5.0
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed Measures ───────────────────── v0.3.3
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Xorg_xcb_util_image_jll ────── v0.4.1+0
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.2+0
#    Installed Contour ────────────────────── v0.6.3
#    Installed PlotUtils ──────────────────── v1.4.4
#    Installed RecipesPipeline ────────────── v0.6.12
#    Installed DelimitedFiles ─────────────── v1.9.1
#    Installed Xorg_libSM_jll ─────────────── v1.2.6+0
#    Installed Xorg_xcb_util_jll ──────────── v0.4.1+0
#    Installed OpenSSL ────────────────────── v1.6.1
#    Installed Xorg_libxkbfile_jll ────────── v1.1.3+0
#    Installed HTTP ───────────────────────── v1.10.19
#    Installed EpollShim_jll ──────────────── v0.0.20230411+1
#    Installed Pango_jll ──────────────────── v1.57.0+0
#    Installed FFMPEG ─────────────────────── v0.4.5
#    Installed Missings ───────────────────── v1.2.0
#    Installed PtrArrays ──────────────────── v1.3.0
#    Installed Showoff ────────────────────── v1.0.3
#    Installed Xorg_xcb_util_keysyms_jll ──── v0.4.1+0
#    Installed HarfBuzz_jll ───────────────── v8.5.1+0
#    Installed SimpleBufferStream ─────────── v1.2.0
#    Installed XZ_jll ─────────────────────── v5.8.1+0
#    Installed xkbcommon_jll ──────────────── v1.13.0+0
#    Installed fzf_jll ────────────────────── v0.61.1+0
#    Installed PlotThemes ─────────────────── v3.3.0
#    Installed FriBidi_jll ────────────────── v1.0.17+0
#    Installed GLFW_jll ───────────────────── v3.4.0+2
#    Installed UnicodeFun ─────────────────── v0.4.1
#    Installed x264_jll ───────────────────── v10164.0.1+0
#    Installed MbedTLS ────────────────────── v1.1.9
#    Installed JLFzf ──────────────────────── v0.1.11
#    Installed libaom_jll ─────────────────── v3.13.1+0
#    Installed Colors ─────────────────────── v0.13.1
#    Installed ExceptionUnwrapping ────────── v0.1.11
#    Installed mtdev_jll ──────────────────── v1.1.7+0
#    Installed Scratch ────────────────────── v1.3.0
#    Installed StatsBase ──────────────────── v0.34.8
#    Installed Dbus_jll ───────────────────── v1.16.2+0
#    Installed ColorTypes ─────────────────── v0.12.1
#    Installed eudev_jll ──────────────────── v3.2.14+0
#    Installed Zstd_jll ───────────────────── v1.5.7+1
#    Installed TensorCore ─────────────────── v0.1.1
#    Installed Xorg_xcb_util_cursor_jll ───── v0.1.6+0
#    Installed Libtiff_jll ────────────────── v4.7.2+0
#    Installed ColorVectorSpace ───────────── v0.11.0
#    Installed Format ─────────────────────── v1.3.7
#    Installed libevdev_jll ───────────────── v1.13.4+0
#    Installed Plots ──────────────────────── v1.41.2
#    Installed libinput_jll ───────────────── v1.28.1+0
#    Installed Ogg_jll ────────────────────── v1.3.6+0
#    Installed Xorg_libXi_jll ─────────────── v1.8.3+0
#    Installed Vulkan_Loader_jll ──────────── v1.3.243+0
#    Installed Qt6ShaderTools_jll ─────────── v6.8.2+1
#    Installed Ghostscript_jll ────────────── v9.55.1+0
#    Installed Qt6Declarative_jll ─────────── v6.8.2+1
#    Installed Xorg_libXcursor_jll ────────── v1.2.4+0
#    Installed AliasTables ────────────────── v1.1.3
#    Installed Xorg_xcb_util_renderutil_jll ─ v0.3.10+0
#    Installed Xorg_libICE_jll ────────────── v1.1.2+0
#    Installed StableRNGs ─────────────────── v1.0.4
#    Installed Graphite2_jll ──────────────── v1.3.15+0
#    Installed libass_jll ─────────────────── v0.17.4+0
#    Installed Wayland_jll ────────────────── v1.24.0+0
#    Installed Latexify ───────────────────── v0.16.10
#    Installed FFMPEG_jll ─────────────────── v8.0.0+0
#    Installed BitFlags ───────────────────── v0.1.9
#    Installed Xorg_xkeyboard_config_jll ──── v2.44.0+0
#    Installed Xorg_libXrandr_jll ─────────── v1.5.5+0
#    Installed DataAPI ────────────────────── v1.16.0
#    Installed FixedPointNumbers ──────────── v0.8.5
#    Installed LAME_jll ───────────────────── v3.100.3+0
#    Installed Qt6Wayland_jll ─────────────── v6.8.2+2
#    Installed Qt6Base_jll ────────────────── v6.8.2+2
#    Installed URIs ───────────────────────── v1.6.1
#    Installed libvorbis_jll ──────────────── v1.3.8+0
#    Installed LaTeXStrings ───────────────── v1.4.0
#    Installed Unzip ──────────────────────── v0.2.0
#    Installed SortingAlgorithms ──────────── v1.2.2
#    Installed ColorSchemes ───────────────── v3.31.0
#    Installed GR ─────────────────────────── v0.73.19
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [91a5bcdd] + Plots v1.41.2
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [66dad0bd] + AliasTables v1.1.3
#   [d1d4a3ce] + BitFlags v0.1.9
#   [35d6a980] + ColorSchemes v3.31.0
#   [3da002f7] + ColorTypes v0.12.1
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.1
#   [f0e56b4a] + ConcurrentUtilities v2.5.0
#   [d38c429a] + Contour v0.6.3
#   [9a962f9c] + DataAPI v1.16.0
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [c87230d0] + FFMPEG v0.4.5
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [1fa38f19] + Format v1.3.7
#   [28b8d3ca] + GR v0.73.19
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.19
#   [1019f520] + JLFzf v0.1.11
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [23fbe1c1] + Latexify v0.16.10
#   [e6f89c97] + LoggingExtras v1.2.0
#   [739be429] + MbedTLS v1.1.9
#   [442fdcdd] + Measures v0.3.3
#   [e1d29d7a] + Missings v1.2.0
#   [4d8831e6] + OpenSSL v1.6.1
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.4
#   [91a5bcdd] + Plots v1.41.2
#   [43287f4e] + PtrArrays v1.3.0
#   [01d81517] + RecipesPipeline v0.6.12
#   [05181044] + RelocatableFolders v1.0.1
#   [6c6a2e73] + Scratch v1.3.0
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [a2af1166] + SortingAlgorithms v1.2.2
#   [860ef19b] + StableRNGs v1.0.4
#   [2913bbd2] + StatsBase v0.34.8
#   [62fd8b95] + TensorCore v0.1.1
#   [5c2747f8] + URIs v1.6.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [41fe7b60] + Unzip v0.2.0
#   [ee1fde0b] + Dbus_jll v1.16.2+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [b22a6f82] + FFMPEG_jll v8.0.0+0
#   [559328eb] + FriBidi_jll v1.0.17+0
#   [0656b61e] + GLFW_jll v3.4.0+2
#   [d2c73de3] + GR_jll v0.73.19+1
#   [61579ee1] + Ghostscript_jll v9.55.1+0
#   [3b182d85] + Graphite2_jll v1.3.15+0
#   [2e76f6c2] + HarfBuzz_jll v8.5.1+0
#   [c1c5ebd0] + LAME_jll v3.100.3+0
#   [88015f11] + LERC_jll v4.0.1+0
#   [89763e89] + Libtiff_jll v4.7.2+0
#   [e7412a2a] + Ogg_jll v1.3.6+0
#   [91d4177d] + Opus_jll v1.5.2+0
#   [36c8627f] + Pango_jll v1.57.0+0
#   [c0090381] + Qt6Base_jll v6.8.2+2
#   [629bc702] + Qt6Declarative_jll v6.8.2+1
#   [ce943373] + Qt6ShaderTools_jll v6.8.2+1
#   [e99dba38] + Qt6Wayland_jll v6.8.2+2
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.24.0+0
#   [ffd25f8a] + XZ_jll v5.8.1+0
#   [f67eecfb] + Xorg_libICE_jll v1.1.2+0
#   [c834827a] + Xorg_libSM_jll v1.2.6+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.4+0
#   [a51aa0fd] + Xorg_libXi_jll v1.8.3+0
#   [ec84b674] + Xorg_libXrandr_jll v1.5.5+0
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.3+0
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.6+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.1+0
#   [2def613f] + Xorg_xcb_util_jll v0.4.1+0
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.1+0
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.10+0
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.2+0
#   [35661453] + Xorg_xkbcomp_jll v1.4.7+0
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.44.0+0
#   [3161d3a3] + Zstd_jll v1.5.7+1
#   [35ca27e7] + eudev_jll v3.2.14+0
#   [214eeab7] + fzf_jll v0.61.1+0
#   [a4ae2306] + libaom_jll v3.13.1+0
#   [0ac62f75] + libass_jll v0.17.4+0
#   [1183f4f0] + libdecor_jll v0.2.2+0
#   [2db6ffa8] + libevdev_jll v1.13.4+0
#   [f638f0a6] + libfdk_aac_jll v2.0.4+0
#   [36db933b] + libinput_jll v1.28.1+0
#   [f27f6e37] + libvorbis_jll v1.3.8+0
#   [009596ad] + mtdev_jll v1.1.7+0
#   [1270edf5] + x264_jll v10164.0.1+0
#   [dfaa095f] + x265_jll v4.1.0+0
#   [d8fb68d0] + xkbcommon_jll v1.13.0+0
# Precompiling project...
#     988.6 ms  ✓ LaTeXStrings
#     817.7 ms  ✓ PtrArrays
#     833.5 ms  ✓ SimpleBufferStream
#     830.0 ms  ✓ DataAPI
#     827.6 ms  ✓ BitFlags
#     840.8 ms  ✓ Contour
#     842.2 ms  ✓ TensorCore
#     853.1 ms  ✓ Measures
#     851.2 ms  ✓ StableRNGs
#     845.7 ms  ✓ DelimitedFiles
#     874.2 ms  ✓ Unzip
#     873.1 ms  ✓ URIs
#     895.2 ms  ✓ ConcurrentUtilities
#     965.2 ms  ✓ Grisu
#    1291.6 ms  ✓ Format
#     561.2 ms  ✓ Scratch
#     651.3 ms  ✓ EpollShim_jll
#     675.0 ms  ✓ SortingAlgorithms
#     677.0 ms  ✓ LoggingExtras
#     693.1 ms  ✓ ExceptionUnwrapping
#     710.7 ms  ✓ Xorg_libICE_jll
#     725.7 ms  ✓ Graphite2_jll
#     729.3 ms  ✓ libfdk_aac_jll
#     731.5 ms  ✓ LAME_jll
#     733.2 ms  ✓ LERC_jll
#     721.6 ms  ✓ fzf_jll
#     812.6 ms  ✓ XZ_jll
#     764.2 ms  ✓ Ogg_jll
#    1297.3 ms  ✓ MbedTLS
#     762.4 ms  ✓ mtdev_jll
#     812.9 ms  ✓ x265_jll
#     811.8 ms  ✓ x264_jll
#     816.4 ms  ✓ libaom_jll
#     771.2 ms  ✓ Opus_jll
#     814.9 ms  ✓ Zstd_jll
#     797.6 ms  ✓ libevdev_jll
#     791.7 ms  ✓ FriBidi_jll
#     827.1 ms  ✓ eudev_jll
#     871.4 ms  ✓ Dbus_jll
#     843.6 ms  ✓ Xorg_xcb_util_jll
#     854.8 ms  ✓ Xorg_libxkbfile_jll
#    2076.4 ms  ✓ UnicodeFun
#    2955.1 ms  ✓ FixedPointNumbers
#     620.0 ms  ✓ Missings
#     591.4 ms  ✓ RelocatableFolders
#     660.1 ms  ✓ AliasTables
#     630.9 ms  ✓ Showoff
#    1467.0 ms  ✓ Ghostscript_jll
#     914.1 ms  ✓ Xorg_libXrandr_jll
#     947.1 ms  ✓ Xorg_libXi_jll
#     876.4 ms  ✓ Xorg_libXcursor_jll
#     869.1 ms  ✓ Xorg_libSM_jll
#     946.9 ms  ✓ Wayland_jll
#     991.0 ms  ✓ HarfBuzz_jll
#     756.5 ms  ✓ libvorbis_jll
#     694.7 ms  ✓ Xorg_xcb_util_keysyms_jll
#     703.0 ms  ✓ Xorg_xcb_util_image_jll
#     744.5 ms  ✓ Libtiff_jll
#     732.2 ms  ✓ libinput_jll
#     722.9 ms  ✓ Xorg_xcb_util_renderutil_jll
#     746.7 ms  ✓ Xorg_xcb_util_wm_jll
#     691.3 ms  ✓ Xorg_xkbcomp_jll
#    1162.2 ms  ✓ JLFzf
#     573.8 ms  ✓ libass_jll
#     594.2 ms  ✓ Pango_jll
#     480.0 ms  ✓ Xorg_xcb_util_cursor_jll
#     441.1 ms  ✓ Xorg_xkeyboard_config_jll
#    1927.7 ms  ✓ OpenSSL
#    1316.5 ms  ✓ ColorTypes
#     508.4 ms  ✓ xkbcommon_jll
#     700.8 ms  ✓ FFMPEG_jll
#    1711.5 ms  ✓ StatsBase
#     521.0 ms  ✓ ColorTypes → StyledStringsExt
#     503.8 ms  ✓ Vulkan_Loader_jll
#     499.1 ms  ✓ FFMPEG
#     585.8 ms  ✓ libdecor_jll
#    2378.5 ms  ✓ Latexify
#     522.7 ms  ✓ GLFW_jll
#    1494.0 ms  ✓ ColorVectorSpace
#     712.6 ms  ✓ Qt6Base_jll
#     550.2 ms  ✓ Latexify → SparseArraysExt
#     424.9 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#     481.4 ms  ✓ Qt6ShaderTools_jll
#     570.0 ms  ✓ GR_jll
#    2864.0 ms  ✓ Colors
#    1229.8 ms  ✓ Qt6Declarative_jll
#     461.1 ms  ✓ Qt6Wayland_jll
#    2284.6 ms  ✓ ColorSchemes
#    9475.8 ms  ✓ HTTP
#     938.9 ms  ✓ FileIO → HTTPExt
#    5710.4 ms  ✓ PlotUtils
#    2114.0 ms  ✓ GR
#     800.2 ms  ✓ GR → GRIJuliaExt
#    1750.3 ms  ✓ PlotThemes
#    2243.4 ms  ✓ RecipesPipeline
#   34216.0 ms  ✓ Plots
#    1775.1 ms  ✓ Plots → IJuliaExt
#    2076.8 ms  ✓ Plots → FileIOExt
#   98 dependencies successfully precompiled in 55 seconds. 192 already precompiled.

# %%
using Plots

plot(hs,[el2s1 eh1s1 el2s2 eh1s2],
    xaxis=:log, yaxis=:log,
    label=["L2 k=1" "H1 k=1" "L2 k=2" "H1 k=2"],
    shape=:auto,
    xlabel="h",ylabel="error norm")

# %%
function slope(hs,errors)
  x = log10.(hs)
  y = log10.(errors)
  linreg = hcat(fill!(similar(x), 1), x) \ y
  linreg[2]
end
# Out:
# slope (generic function with 1 method)

# %%
slope(hs,el2s1)
slope(hs,el2s2)
# Out:
# 3.000000000212429

# %%
slope(hs,eh1s1)
slope(hs,eh1s2)
# Out:
# 2.0000597414740624
