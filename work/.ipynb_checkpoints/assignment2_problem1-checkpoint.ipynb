# %%
import Gmsh: gmsh
using Gridap, GridapGmsh

# %%
function create_square_model(h)
    gmsh.initialize()
    gmsh.model.add("unit_square");
    gmsh.model.geo.addPoint(0.0, 0.0, 0.0, h, 1); # last argument is optional identifier, unique per dimension
    gmsh.model.geo.addPoint(1.0, 0.0, 0.0, h, 2);
    gmsh.model.geo.addPoint(1.0, 1.0, 0.0, h, 3);
    gmsh.model.geo.addPoint(0.0, 1.0, 0.0, h, 4);
    gmsh.model.geo.addLine(1, 2, 1); 
    gmsh.model.geo.addLine(2, 3, 2); # line 2 goes from point 2 to point 3
    gmsh.model.geo.addLine(3, 4, 3);
    gmsh.model.geo.addLine(4, 1, 4);
    
    gmsh.model.geo.addCurveLoop([1, 2, 3, 4], 1);

    gmsh.model.geo.addPlaneSurface([1], 1);

    gmsh.model.geo.synchronize();

    # Define physical groups without the string argument
    edges_tag = gmsh.model.addPhysicalGroup(1, [1, 2, 3, 4])   # edges
    corners_tag = gmsh.model.addPhysicalGroup(0, [1, 2, 3, 4]) # corners
    domain_tag = gmsh.model.addPhysicalGroup(2, [1])           # surface
    
    # Set names for the physical groups
    gmsh.model.setPhysicalName(1, edges_tag, "boundary")
    gmsh.model.setPhysicalName(0, corners_tag, "boundary")
    gmsh.model.setPhysicalName(2, domain_tag, "domain")

    gmsh.model.mesh.generate(2); # dimension is 2
    
    model = GmshDiscreteModel(gmsh);
    gmsh.finalize();
    return model
end
# Out:
# create_square_model (generic function with 1 method)

# %%
h = 0.05; # target mesh size
model = create_square_model(h) # fix above function above using the tutorial
order = 1
reffe = ReferenceFE(lagrangian, Float64, order)
V = TestFESpace(model, reffe, conformity=:H1, dirichlet_tags="boundary")
U = TrialFESpace(V, 0.0)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.000693742s, CPU 0.000267s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0133477s, CPU 0.007486s)
# Info    : 513 nodes 1028 elements
# TrialFESpace()

# %%
Ω = Triangulation(model)
dΩ = Measure(Ω, 2 * order)
# Out:
# GenericMeasure()

# %%
n=5
Δt, T = 2.0^(-n), 1.0 # time step, final time
a0 = 0.05 # diffusion coefficient
num_steps = Int(T / Δt)
# Out:
# 32

# %%
f(t, x) = sin(π * x[1]) * sin(2 * π * x[2]) * (5 * a0 * π^2 * (2 - cos(t)) + sin(t))
f(t) = x -> f(t,x)
# Out:
# f (generic function with 2 methods)

# %%
u_exact(t, x) = sin(pi * x[1]) * sin(2pi * x[2]) * (2 - cos(t)) # fill in the rests
u₀ = x -> sin(pi * x[1]) * sin(2pi * x[2]) # fill in initial condition based on u_exact
# Out:
# #47 (generic function with 1 method)

# %%
if !isdir("tmp") mkdir("tmp") end # for storing solution
# assemble the left hand side:
a(u, v) = ∫( (1/Δt) * u * v + a0 * (∇(u) ⋅ ∇(v)) )dΩ   # fill in the rest
aa = assemble_matrix(a, U, V)
# Out:
# 433×433 SparseArrays.SparseMatrixCSC{Float64, Int64} with 2873 stored entries:
# ⎡⠑⢄⠈⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡖⡏⠹⣤⡤⣀⣁⠀⠒⠀⠀⠀⠀⠐⢶⣔⡲⢿⡤⡠⎤
# ⎢⠂⠀⠱⣦⡀⠀⢀⠀⠠⠀⠀⡀⡄⠀⠀⢀⠀⠀⡀⠀⠈⠊⠈⠊⠐⠂⠆⠀⠉⣠⠀⠠⠰⠁⠂⠉⠂⠓⠑⠉⎥
# ⎢⠀⠀⠀⠈⠻⣦⡈⠄⠀⠀⠀⠀⠀⢀⠄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⡀⠘⡵⠈⠆⠙⠂⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠐⠂⠌⠱⣦⡐⠬⢉⠀⡄⠈⠄⣰⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠹⢰⠺⣦⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠂⠀⠀⡐⡌⢿⣷⠠⣆⡠⢄⡀⢁⠀⠀⠀⠀⠀⢂⠀⠂⠀⠀⠃⣰⢰⣐⢽⠪⠔⠀⠀⠠⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠠⠀⠀⠃⠐⠠⢦⠟⣥⡺⢕⠲⣠⡇⠀⠀⠀⠀⠀⠤⠀⠀⠀⠧⠃⠐⢄⡃⠄⠖⢢⠀⠀⠀⠀⠄⠀⎥
# ⎢⠀⠀⠀⠉⠀⢀⡀⠉⠀⢎⢞⢎⡿⣯⣹⣁⢂⠲⡓⠠⠀⠀⠁⡀⠀⠄⣂⢁⡠⠣⡕⢎⠄⠁⠀⠀⢠⠀⠔⠄⎥
# ⎢⠀⠀⠀⢀⠀⠁⢀⣡⠄⢈⠘⣢⠗⢺⠕⢅⠨⠂⡈⡕⢂⠄⡤⡄⠒⡂⢤⣁⢨⣧⣲⡻⡲⢘⡨⠀⠰⠀⠄⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⢨⡐⠢⠂⡱⣮⣥⢂⡤⣎⠅⠄⠀⠀⡀⠉⠒⢀⢣⠂⢁⠼⠒⠍⡀⡀⠨⡄⎥
# ⎢⠀⢀⠀⠈⠀⠀⠀⠀⠀⠀⠀⠀⠙⡈⢆⠬⠡⢛⠱⢆⡪⠅⢁⡁⠀⠀⠀⠌⠈⠪⢘⡔⠿⢶⡤⢒⡬⣁⠐⣂⎥
# ⎢⡼⠭⡢⠀⠀⠀⠀⠀⠠⢀⠀⠀⠀⠀⠈⠔⡠⢯⠎⠎⠑⢄⣀⠄⠄⠂⡀⡠⠢⠰⢐⢡⠘⡀⠶⠉⠱⢷⠀⢑⎥
# ⎢⠓⣦⡢⠀⠀⠀⠀⠀⠠⠀⠀⠃⠁⠠⠀⠯⠁⠅⠅⠰⠀⠜⠟⢅⠀⠀⠆⠰⠤⠒⠐⠀⠄⠁⢀⠋⠤⢖⡘⠥⎥
# ⎢⠀⢫⠰⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠄⠸⠠⠀⠀⠀⠀⠠⠁⠀⠀⠻⣦⣠⠀⡆⠀⠄⠘⠈⠀⠀⠀⠋⢴⡣⡀⎥
# ⎢⠁⠘⠈⠁⠐⠲⣄⡀⢉⣠⠭⠃⠌⢘⠄⢳⡄⠈⡀⠄⠀⡨⢈⡁⠀⠚⡛⢌⣑⢄⢜⡺⡬⠓⠀⠀⢁⠀⠁⠂⎥
# ⎢⠘⠀⠃⣠⢖⡤⣰⡒⢐⢲⠐⢄⠤⡊⠦⣶⠘⢀⡢⡀⢈⡂⢠⠃⠈⠉⠑⢜⢑⢔⢱⡵⠤⠲⠀⠀⡉⢁⡁⠀⎥
# ⎢⠀⠀⠀⡀⠢⠄⠈⠛⡳⡓⠉⠌⡱⢍⣼⡺⠩⠒⢒⠴⠔⣐⠐⠀⣀⠁⣲⡱⢕⡶⢑⣴⣣⡄⠐⠈⠠⠐⠀⠤⎥
# ⎢⢀⠀⠔⠂⠳⠀⠀⠀⠐⠁⠸⣁⠄⠁⣘⢊⣁⡔⢻⣇⠒⠠⠄⠁⠂⠀⢦⠋⢠⡃⠉⠾⡻⣮⡂⠘⠘⠀⠀⠁⎥
# ⎢⢘⢷⡌⠀⠀⠀⠀⠀⠀⡀⠀⠀⠀⠀⠂⠊⡜⠄⢠⢋⡜⠃⡤⠐⠀⠀⠀⠀⠀⠀⡐⠀⣈⠈⠛⢄⠀⠓⠢⡄⎥
# ⎢⣼⣎⢬⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠒⠐⠂⠀⠨⠆⢫⢵⣆⢠⢇⢋⣄⠁⠐⠇⢈⢀⠂⠒⠀⢤⠀⠟⢅⠋⢹⎥
# ⎣⠀⡫⡕⠀⠀⠀⠀⠀⠀⠀⠀⠁⠐⠅⠀⠁⠂⠦⠰⢠⢄⢀⠖⡌⠉⠪⠡⠀⠁⠈⠀⡄⠄⠀⠈⠦⣏⣀⠵⢇⎦

# %%
createpvd("heat") do pvd
    uh = interpolate_everywhere(u₀, U) # initial condition
    pvd[0] = createvtk(Ω, "tmp/heat_0.vtu", cellfields=["uh" => uh, "e" => x -> 0.0])
    e = nothing # to make the error accessible after the loop
    for n in 1:num_steps # start time-stepping
        tₙ = n * Δt
        tₙ₋₁ = (n-1) * Δt
        
        # assemble the right hand side
        b(v) = ∫( (1/Δt)*uh*v + f(tₙ)*v )dΩ  # fill in the rest
        bb = assemble_vector(b, V)
        uh = FEFunction(U, aa \ bb) # solve for next value
        
        # save numerical solution and error
        vtufilename = "tmp/heat_$n.vtu"
        u_exact_n = x -> u_exact(tₙ, x)
        e = u_exact_n - uh
        pvd[tₙ] = createvtk(Ω, vtufilename, cellfields=["uh" => uh, "e" => e])
    end
    el2 = sqrt(sum( ∫( e*e )*dΩ )) # fill in the rest
    println("L2 error norm: $el2")
end
# Out:
# MethodError: no method matching *(::Float64, ::var"#1#2"{Float64})
# The function `*` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   *(::Any, ::Any, ::Any, ::Any...)
#    @ Base operators.jl:596
#   *(::Real, ::Complex{Bool})
#    @ Base complex.jl:330
#   *(::typeof(gradient), ::Function)
#    @ Gridap ~/.julia/packages/Gridap/dk0DA/src/Fields/DiffOperators.jl:102
#   ...
#
#
# Stacktrace:
#   [1] *(::Float64, ::Function, ::Gridap.FESpaces.SingleFieldFEBasis{Gridap.FESpaces.TestBasis, ReferenceDomain})
#     @ Base ./operators.jl:596
#   [2] (::var"#b#97"{Float64})(v::Gridap.FESpaces.SingleFieldFEBasis{Gridap.FESpaces.TestBasis, ReferenceDomain})
#     @ Main ./In[33]:10
#   [3] assemble_vector(f::var"#b#97"{Float64}, a::Gridap.FESpaces.GenericSparseMatrixAssembler, V::Gridap.FESpaces.UnconstrainedFESpace{Vector{Float64}, Gridap.FESpaces.NodeToDofGlue{Int32}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/dk0DA/src/FESpaces/Assemblers.jl:306
#   [4] assemble_vector(f::Function, V::Gridap.FESpaces.UnconstrainedFESpace{Vector{Float64}, Gridap.FESpaces.NodeToDofGlue{Int32}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/dk0DA/src/FESpaces/Assemblers.jl:374
#   [5] (::var"#92#95")(pvd::WriteVTK.CollectionFile)
#     @ Main ./In[33]:11
#   [6] paraview_collection(f::var"#92#95", args::String; kwargs::@Kwargs{})
#     @ WriteVTK ~/.julia/packages/WriteVTK/Be3qm/src/WriteVTK.jl:217
#   [7] paraview_collection(f::Function, args::String)
#     @ WriteVTK ~/.julia/packages/WriteVTK/Be3qm/src/WriteVTK.jl:213
#   [8] #createpvd#32
#     @ ~/.julia/packages/Gridap/dk0DA/src/Visualization/Vtk.jl:27 [inlined]
#   [9] createpvd(::Function, ::String)
#     @ Gridap.Visualization ~/.julia/packages/Gridap/dk0DA/src/Visualization/Vtk.jl:26
#  [10] top-level scope
#     @ In[33]:1
