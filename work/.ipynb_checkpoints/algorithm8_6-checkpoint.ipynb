# %%
function EMpath(u0,T,N,d,m,fhandle,ghandle,kappa0, M; rng)
    #small step
    Dtref = T/N 
    #large step
    Dt = kappa0*Dtref
    #number of large steps
    NN = div(N,kappa0)
    
    #initialization of solution
    u = zeros(d,M,NN+1)
    #initializaion of time grid
    t = zeros(NN+1)
    #initialization of gdW
    gdW=zeros(d,M)

    #current u, start with u0
    u_n = copy(u0)

    for n in 1:NN
        t[n] = (n-1)*Dt
        u[:,:,n] = u_n
        
        #dW = sqrt(Dtref) .* dropdims(sum(randn(rng, m, M, kappa0); dims=3); dims=3)
        dW = zeros(Float64, m, M)
        for r in 1:kappa0
            dW .+= sqrt(Dtref) .* randn(rng, m, M)
        end


        for mm in 1:M
            gdW[:,mm] = ghandle(view(u_n, :, mm)) * dW[:, mm]
        end
        u_n .= u_n.+ Dt.*fhandle(u_n).+gdW
    end
    t[NN+1] = NN*Dt
    u[:,:,NN+1] .= u_n
    return t, u
end
# Out:
# EMpath (generic function with 1 method)

# %%
using Random
function runEMpath(u0,T,Nref,d,m,fhandle,ghandle,kappas,M)
    #S = 0.0 #counter for sum
    S = zeros(length(kappas))
    #block size
    Mstep = 1000 
    #indexing for the blocks
    m0 = 1
    
    #replicates the global stream best (I think) from reading documentation
    rng = MersenneTwister(69)
    
    for mm in 1:Mstep:M
        #num of samples in this block (not needed if M is a multiple of Mstep)
        MM = min(Mstep, M - mm + 1) 
        #initial values for MM samples
        u00 = u0[:, mm:m0+MM-1]

        savedState = copy(rng)
        rng = copy(savedState)
        #reference solution and time grid using EMpath function (Algorithm 8.5) 
        tref, uref = EMpath(u00, T, Nref, d, m, fhandle, ghandle, 1, MM; rng = rng)

        for (i,kappa) in pairs(kappas)
            rng = copy(savedState)
            #coarse solution and time grid using EMpath function (Algortithm 8.5)
            t, u = EMpath(u00, T, Nref, d, m, fhandle, ghandle, kappa, MM; rng = rng)
            
            #error at the last time slice 
            err = u[:, :, end] .- uref[:, :, end]

            #add the sum of the elementwise squared errors to the counter
            #S += sum(err .* err)
            S[i] += sum(err .* err)
        end
        #set new indexing for m0 since we are moving on to next block
        m0 += MM
    end

    #operations to get RMS 
    rmsErr = sqrt.(S ./ M) 

    return rmsErr
end
# Out:
# runEMpath (generic function with 1 method)

# %%
# parameters
T = 1.0
Nref = 2^12
d = 1
m = 1
M = 5000
####################
#Geometric Brownian motion Eq. (8.11) in Lord
r = 2.0
σ = 1.0

fhandle(u) = r .* u
ghandle(uvec) = reshape([σ * uvec[1]], 1, 1)
##########################

u0 = ones(d, M)

kappas = [2, 4, 8, 16, 32, 64, 128]

rmsErr = runEMpath(u0, T, Nref, d, m, fhandle, ghandle, kappas, M)

Δtref = T/Nref
dts = kappas .* Δtref

println("dt values:")
println(dts)

println("RMS errors:")
println(rmsErr)
# Out:
# DimensionMismatch: second dimension of A, 1, does not match length of x, 1000
#
# Stacktrace:
#  [1] gemv!
#    @ /usr/local/julia/share/julia/stdlib/v1.11/LinearAlgebra/src/matmul.jl:438 [inlined]
#  [2] generic_matvecmul!
#    @ /usr/local/julia/share/julia/stdlib/v1.11/LinearAlgebra/src/matmul.jl:79 [inlined]
#  [3] _mul!
#    @ /usr/local/julia/share/julia/stdlib/v1.11/LinearAlgebra/src/matmul.jl:73 [inlined]
#  [4] mul!
#    @ /usr/local/julia/share/julia/stdlib/v1.11/LinearAlgebra/src/matmul.jl:70 [inlined]
#  [5] mul!
#    @ /usr/local/julia/share/julia/stdlib/v1.11/LinearAlgebra/src/matmul.jl:253 [inlined]
#  [6] *(A::Matrix{Float64}, x::Vector{Float64})
#    @ LinearAlgebra /usr/local/julia/share/julia/stdlib/v1.11/LinearAlgebra/src/matmul.jl:56
#  [7] EMpath(u0::Matrix{Float64}, T::Float64, N::Int64, d::Int64, m::Int64, fhandle::typeof(fhandle), ghandle::typeof(ghandle), kappa0::Int64, M::Int64; rng::MersenneTwister)
#    @ Main ./In[315]:32
#  [8] runEMpath(u0::Matrix{Float64}, T::Float64, Nref::Int64, d::Int64, m::Int64, fhandle::Function, ghandle::Function, kappas::Vector{Int64}, M::Int64)
#    @ Main ./In[316]:22
#  [9] top-level scope
#    @ In[317]:20

# %%
using Plots 
x = range(minimum(dts),maximum(dts),10)
# log-log plot
plot(dts, rmsErr, xaxis=:log, yaxis=:log, marker=:circle, label="Euler-Maruyama RMS error")
plot!(x,x.^0.5, xaxis=:log, yaxis=:log, label="Reference line")
