# %%
import Gmsh: gmsh
import Pkg; Pkg.add("FFTW"); Pkg.add("SpecialFunctions")
using Gridap, GridapGmsh
using Random, LinearAlgebra, FFTW
using SpecialFunctions  # gamma, besselk if you later want the covariance form
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`

# %%
function create_square_model(h)
    gmsh.initialize()
    gmsh.model.add("unit_square")
    gmsh.model.geo.addPoint(0,0,0,1,1) # last argument is optional identifier, unique per dimension
    gmsh.model.geo.addPoint(1,0,0,1,2)
    gmsh.model.geo.addPoint(1,1,0,1,3)
    gmsh.model.geo.addPoint(0,1,0,1,4)
    gmsh.model.geo.addLine(1,2,1)
    gmsh.model.geo.addLine(2,3,2) # line 2 goes from point 2 to point 3
    gmsh.model.geo.addLine(3,4,3)
    gmsh.model.geo.addLine(4,1,4)
        
    gmsh.model.geo.addCurveLoop([1,2,3,4],1)
        
    gmsh.model.geo.addPlaneSurface([1],1)

    N = Int(round(1/h))  # number of elements per edge

    gmsh.model.geo.mesh.setTransfiniteCurve(1, N+1)
    gmsh.model.geo.mesh.setTransfiniteCurve(2, N+1)
    gmsh.model.geo.mesh.setTransfiniteCurve(3, N+1)
    gmsh.model.geo.mesh.setTransfiniteCurve(4, N+1)

    #triangulation
    gmsh.model.geo.mesh.setTransfiniteSurface(1)

    gmsh.model.geo.synchronize()

    # Define physical groups without the string argument
    edges_tag = gmsh.model.addPhysicalGroup(1, [1, 2, 3, 4])   # edges
    corners_tag = gmsh.model.addPhysicalGroup(0, [1, 2, 3, 4]) # corners
    domain_tag = gmsh.model.addPhysicalGroup(2, [1])           # surface
    
    # Set names for the physical groups
    gmsh.model.setPhysicalName(1, edges_tag, "boundary")
    gmsh.model.setPhysicalName(0, corners_tag, "boundary")
    gmsh.model.setPhysicalName(2, domain_tag, "domain")
    gmsh.model.mesh.generate(2)

    model = GmshDiscreteModel(gmsh);
    gmsh.finalize();
    return model
end
# Out:
# create_square_model (generic function with 1 method)

# %%
h = 1/128; # target mesh size
model = create_square_model(h) # fix above function above using the tutorial
order = 1
reffe = ReferenceFE(lagrangian, Float64, order)
V = FESpace(model, reffe, conformity=:H1)
Ω = Triangulation(model)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.00133514s, CPU 0.002276s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Transfinite)
# Info    : Done meshing 2D (Wall 0.00248918s, CPU 0.002464s)
# Info    : 1089 nodes 2180 elements
# BodyFittedTriangulation()

# %%
using Random, FFTW, SpecialFunctions

# Matérn covariance ρ(r)
function matern_rho(r::Float64; σ=1.0, ν=1.0, ℓ=0.2)
    r == 0.0 && return σ^2
    z = sqrt(2ν) * r / ℓ
    c = σ^2 * (2.0^(1.0-ν)) / gamma(ν)
    return c * (z^ν) * besselk(ν, z)
end

# your "∂x(a)" / "∂y(b)" distance map (wrap-around)
partial_dist(a::Int, M::Int, h::Float64) = min(a, M - a) * h

"""
Circulant embedding sample on [0,1]^2 structured grid (nodes N+1 per axis)
using embedding size M (>= 2*(N+1) recommended).
Returns ΔW_grid of size (N+1, N+1) with covariance Δt ρ(|x-y|) approximately.
"""
function sample_matern_circulant_increment(N::Int; Δt=1e-3, σ=1.0, ν=1.0, ℓ=0.2,
                                          rng=Random.default_rng(),
                                          M::Int = 2^(ceil(Int, log2(2*(N+1)))))

    h = 1.0 / N

    # First column of block-circulant covariance
    C = Array{Float64}(undef, M, M)
    for a in 0:M-1, b in 0:M-1
        dx = min(a, M-a) * h
        dy = min(b, M-b) * h
        r  = hypot(dx, dy)
        C[a+1, b+1] = Δt * matern_rho(r; σ=σ, ν=ν, ℓ=ℓ)
    end

    Λ = real(fft(C))

    Λmin = minimum(Λ)
    if Λmin < -1e-10
        @warn "Embedding not PSD (min eigenvalue = $Λmin). Increase M or adjust (ν,ℓ)."
    end
    Λ .= max.(Λ, 0.0)

    # Proper complex N(0,1) with E|ξ|^2 = 1
    ξ  = (randn(rng, M, M) .+ im*randn(rng, M, M)) ./ sqrt(2)

    Ŷ = sqrt.(Λ) .* ξ

    # Correct for ifft normalization
    Y  = real(ifft(Ŷ)) * sqrt(M*M)

    return Y[1:(N+1), 1:(N+1)]
end
# Out:
# sample_matern_circulant_increment

# %%
N = Int(round(1/h))

Δt = 1e-3
σ, ν, ℓ = 1.0, 1.2, 0.15
rng = MersenneTwister(1)

ΔW_grid = sample_matern_circulant_increment(N; Δt=Δt, σ=σ, ν=ν, ℓ=ℓ, rng=rng)

# nearest-node indexing for interpolation onto FE space
function ij_from_x(x, N)
    i = clamp(round(Int, x[1]*N), 0, N)
    j = clamp(round(Int, x[2]*N), 0, N)
    return i, j
end

ΔW_fe = interpolate_everywhere(x -> begin
    i, j = ij_from_x(x, N)
    ΔW_grid[i+1, j+1]
end, V)

writevtk(Ω, "ΔW_matern_circulant", cellfields=["ΔW" => ΔW_fe])
# Out:
# (["ΔW_matern_circulant.vtu"],)
